# %%
import networkx as nx
import pickle
import os

pkl_directory = '../data/trimmed_networks_pkl'

graphs = {}

for filename in os.listdir(pkl_directory):
    if filename.endswith('.pkl'):
        filepath = os.path.join(pkl_directory, filename)
        with open(filepath, 'rb') as f:
            G = pickle.load(f)
            graphs[filename] = G  # Store the graph in the dictionary
            print(f"Loaded graph from {filename}:")
            print(f"Number of nodes: {G.number_of_nodes()}, Number of edges: {G.number_of_edges()}")

for graph_name, graph in graphs.items():
    print(f"Graph: {graph_name}, Nodes: {graph.number_of_nodes()}, Edges: {graph.number_of_edges()}")
# Out:
# Loaded graph from 2_resource_allocation_naive.pkl:
# Number of nodes: 18643, Number of edges: 42691
# Loaded graph from 2_simple_disparity_filter.pkl:
# Number of nodes: 18643, Number of edges: 336278
# Loaded graph from 1_simple_disparity_filter.pkl:
# Number of nodes: 18643, Number of edges: 443701
# Loaded graph from 1_resource_allocation_naive.pkl:
# Number of nodes: 18643, Number of edges: 15588
# Graph: 2_resource_allocation_naive.pkl, Nodes: 18643, Edges: 42691
# Graph: 2_simple_disparity_filter.pkl, Nodes: 18643, Edges: 336278
# Graph: 1_simple_disparity_filter.pkl, Nodes: 18643, Edges: 443701
# Graph: 1_resource_allocation_naive.pkl, Nodes: 18643, Edges: 15588

# %%
from networkx.algorithms.community import greedy_modularity_communities
from networkx.algorithms.community import label_propagation_communities
from networkx.algorithms.community import modularity
from networkx.algorithms.assortativity import attribute_assortativity_coefficient
from networkx.algorithms.community import louvain_communities

#graph_rn_2 = graphs['2_resource_allocation_naive.pkl']


""" # Find the largest connected component
largest_cc_nodes_rn_2 = max(nx.connected_components(graph_rn_2), key=len)

# Create a subgraph of only the largest connected component
largest_cc_graph_rn_2 = graph_rn_2.subgraph(largest_cc_nodes_rn_2).copy() """

#graph_rn_1 = graphs['1_resource_allocation_naive.pkl']

""" # Find the largest connected component
largest_cc_nodes_rn_1 = max(nx.connected_components(graph_rn_1), key=len)

# Create a subgraph of only the largest connected component
largest_cc_graph_rn_1 = graph_rn_2.subgraph(largest_cc_nodes_rn_1).copy()
 """
#graph_sd_1 = graphs['1_simple_disparity_filter.pkl']

""" # Find the largest connected component
largest_cc_nodes_sd_1 = max(nx.connected_components(graph_sd_1), key=len)

# Create a subgraph of only the largest connected component
largest_cc_graph_sd_1 = graph_rn_2.subgraph(largest_cc_nodes_sd_1).copy() """

#graph_sd_2 = graphs['2_simple_disparity_filter.pkl']

""" # Find the largest connected component
largest_cc_nodes_sd_2 = max(nx.connected_components(graph_sd_2), key=len)

# Create a subgraph of only the largest connected component
largest_cc_graph_sd_2 = graph_rn_2.subgraph(largest_cc_nodes_sd_2).copy() """


# Function to remove isolates from a graph
def remove_isolates(graph):
    isolates = list(nx.isolates(graph))
    graph.remove_nodes_from(isolates)

# Modify the graphs in place
remove_isolates(graphs['2_resource_allocation_naive.pkl'])
remove_isolates(graphs['1_resource_allocation_naive.pkl'])
remove_isolates(graphs['1_simple_disparity_filter.pkl'])
remove_isolates(graphs['2_simple_disparity_filter.pkl'])

# Assign the modified graphs back to the variables
graph_rn_2 = graphs['2_resource_allocation_naive.pkl']
graph_rn_1 = graphs['1_resource_allocation_naive.pkl']
graph_sd_1 = graphs['1_simple_disparity_filter.pkl']
graph_sd_2 = graphs['2_simple_disparity_filter.pkl']



# Function to keep only the largest connected component of a graph
def keep_largest_component(graph):
    # Get the largest connected component
    largest_cc = max(nx.connected_components(graph), key=len)
    # Create a subgraph with only the nodes in the largest connected component
    return graph.subgraph(largest_cc).copy()

# Assign the largest component of each graph to new variables
graph_rn_2 = keep_largest_component(graphs['2_resource_allocation_naive.pkl'])
graph_rn_1 = keep_largest_component(graphs['1_resource_allocation_naive.pkl'])
graph_sd_1 = keep_largest_component(graphs['1_simple_disparity_filter.pkl'])
graph_sd_2 = keep_largest_component(graphs['2_simple_disparity_filter.pkl'])

# Resulting graphs are now stored in the respective variables

# %%
""" def process_graph(graph):
    # Remove isolates
    graph.remove_nodes_from(list(nx.isolates(graph)))
    
    # Get all connected components
    connected_components = list(nx.connected_components(graph))
    
    # Find the largest connected component
    largest_cc_size = len(max(connected_components, key=len))
    
    # Get sizes of all other connected components
    other_cc_sizes = [len(cc) for cc in connected_components if len(cc) != largest_cc_size]
    
    # Calculate average size of other connected components
    avg_size_other_cc = sum(other_cc_sizes) / len(other_cc_sizes) if other_cc_sizes else 0
    
    return avg_size_other_cc

# List of graphs
graphs = {
    '2_resource_allocation_naive': graph_rn_2,
    '1_resource_allocation_naive': graph_rn_1,
    '1_simple_disparity_filter': graph_sd_1,
    '2_simple_disparity_filter': graph_sd_2
}

# Process each graph and store results
results = {name: process_graph(graph) for name, graph in graphs.items()}

# Display the results
for graph_name, avg_size in results.items():
    print(f"Average size of connected components (excluding largest) for {graph_name}: {avg_size}") """
# Out:
# ' def process_graph(graph):\n    # Remove isolates\n    graph.remove_nodes_from(list(nx.isolates(graph)))\n    \n    # Get all connected components\n    connected_components = list(nx.connected_components(graph))\n    \n    # Find the largest connected component\n    largest_cc_size = len(max(connected_components, key=len))\n    \n    # Get sizes of all other connected components\n    other_cc_sizes = [len(cc) for cc in connected_components if len(cc) != largest_cc_size]\n    \n    # Calculate average size of other connected components\n    avg_size_other_cc = sum(other_cc_sizes) / len(other_cc_sizes) if other_cc_sizes else 0\n    \n    return avg_size_other_cc\n\n# List of graphs\ngraphs = {\n    \'2_resource_allocation_naive\': graph_rn_2,\n    \'1_resource_allocation_naive\': graph_rn_1,\n    \'1_simple_disparity_filter\': graph_sd_1,\n    \'2_simple_disparity_filter\': graph_sd_2\n}\n\n# Process each graph and store results\nresults = {name: process_graph(graph) for name, graph i
# ...

# %%
""" import networkx as nx

def average_density_excluding_largest(graph):
    # Remove isolates
    graph.remove_nodes_from(list(nx.isolates(graph)))
    
    # Get all connected components
    connected_components = list(nx.connected_components(graph))
    
    # Find the largest connected component
    largest_cc = max(connected_components, key=len)
    
    # Calculate densities of all other connected components
    densities = []
    for component in connected_components:
        if component != largest_cc:
            subgraph = graph.subgraph(component)
            densities.append(nx.density(subgraph))
    
    # Calculate the average density
    avg_density = sum(densities) / len(densities) if densities else 0
    
    return avg_density

# List of graphs
graphs = {
    '2_resource_allocation_naive': graph_rn_2,
    '1_resource_allocation_naive': graph_rn_1,
    '1_simple_disparity_filter': graph_sd_1,
    '2_simple_disparity_filter': graph_sd_2
}

# Process each graph and store results
results = {name: average_density_excluding_largest(graph) for name, graph in graphs.items()}

# Display the results
for graph_name, avg_density in results.items():
    print(f"Average density of connected components (excluding largest) for {graph_name}: {avg_density}") """
# Out:
# ' import networkx as nx\n\ndef average_density_excluding_largest(graph):\n    # Remove isolates\n    graph.remove_nodes_from(list(nx.isolates(graph)))\n    \n    # Get all connected components\n    connected_components = list(nx.connected_components(graph))\n    \n    # Find the largest connected component\n    largest_cc = max(connected_components, key=len)\n    \n    # Calculate densities of all other connected components\n    densities = []\n    for component in connected_components:\n        if component != largest_cc:\n            subgraph = graph.subgraph(component)\n            densities.append(nx.density(subgraph))\n    \n    # Calculate the average density\n    avg_density = sum(densities) / len(densities) if densities else 0\n    \n    return avg_density\n\n# List of graphs\ngraphs = {\n    \'2_resource_allocation_naive\': graph_rn_2,\n    \'1_resource_allocation_naive\': graph_rn_1,\n    \'1_simple_disparity_filter\': graph_sd_1,\n    \'2_simple_disparity_filter\': graph_s
# ...

# %%
""" from itertools import combinations

def reconnect_graph_min_edges(graph):
    if nx.is_connected(graph):
        print("The graph is already connected.")
        return graph, []

    # Step 1: Identify connected components
    components = list(nx.connected_components(graph))
    component_graph = nx.Graph()
    
    # Step 2: Create a component graph (nodes are connected components)
    for i, component in enumerate(components):
        component_graph.add_node(i, nodes=list(component))
    
    # Step 3: Add edges between components (weights can be based on custom logic)
    for (i, comp1), (j, comp2) in combinations(enumerate(components), 2):
        # Define edge weight (can be based on distance or other criteria)
        # For simplicity, weight is set to 1 here
        component_graph.add_edge(i, j, weight=1)
    
    # Step 4: Find the Minimum Spanning Tree (MST) of the component graph
    mst = nx.minimum_spanning_tree(component_graph)

    # Step 5: Add the edges back to the original graph
    new_edges = []
    for u, v in mst.edges():
        # Pick any pair of nodes from the two connected components to connect
        node_u = list(components[u])[0]
        node_v = list(components[v])[0]
        graph.add_edge(node_u, node_v)
        new_edges.append((node_u, node_v))

    return graph, new_edges

# Example usage

# Reconnect the graph
connected_G, added_edges = reconnect_graph_min_edges(graph_rn_2)

print("Added edges to reconnect graph:", added_edges)
print("Number of edges added to reconnect graph:", len(added_edges))
print("Is the graph connected now?", nx.is_connected(connected_G))
print(len(graph_rn_2.edges)) """
# Out:
# ' from itertools import combinations\n\ndef reconnect_graph_min_edges(graph):\n    if nx.is_connected(graph):\n        print("The graph is already connected.")\n        return graph, []\n\n    # Step 1: Identify connected components\n    components = list(nx.connected_components(graph))\n    component_graph = nx.Graph()\n    \n    # Step 2: Create a component graph (nodes are connected components)\n    for i, component in enumerate(components):\n        component_graph.add_node(i, nodes=list(component))\n    \n    # Step 3: Add edges between components (weights can be based on custom logic)\n    for (i, comp1), (j, comp2) in combinations(enumerate(components), 2):\n        # Define edge weight (can be based on distance or other criteria)\n        # For simplicity, weight is set to 1 here\n        component_graph.add_edge(i, j, weight=1)\n    \n    # Step 4: Find the Minimum Spanning Tree (MST) of the component graph\n    mst = nx.minimum_spanning_tree(component_graph)\n\n    # Step 5
# ...

# %%
""" # Define a function to compute and print assortativity for a given attribute
def compute_assortativity(graph, attribute):
    try:
        assortativity = nx.attribute_assortativity_coefficient(graph, attribute)
        print(f"Assortativity for '{attribute}': {assortativity}")
        return assortativity
    except Exception as e:
        print(f"Error computing assortativity for '{attribute}': {e}")
        return None

# Example for Graph 1
print("Graph simple count and disparity filter with threshold 0.5 Assortativities:")
compute_assortativity(largest_cc_graph_sd_1, "most_frequent_locality")
compute_assortativity(largest_cc_graph_sd_1, "most_frequent_parasite_group")
compute_assortativity(largest_cc_graph_sd_1, "animals_group")

# Example for Graph 2
print("\nGraph simple count and disparity filter with threshold 0.57 Assortativities:")
compute_assortativity(largest_cc_graph_sd_2, "most_frequent_locality")
compute_assortativity(largest_cc_graph_sd_2, "most_frequent_parasite_group")
compute_assortativity(largest_cc_graph_sd_2, "animals_group")

# Example for Graph 3
print("\nGraph resource allocation and naive with threshold 0.0349 on score (not nij) Assortativities:")
compute_assortativity(largest_cc_graph_rn_1, "most_frequent_locality")
compute_assortativity(largest_cc_graph_rn_1, "most_frequent_parasite_group")
compute_assortativity(largest_cc_graph_rn_1, "animals_group")

print("\nGraph resource allocation and naive with threshold 0.01745 on score (not nij) Assortativities:")
compute_assortativity(largest_cc_graph_rn_2, "most_frequent_locality")
compute_assortativity(largest_cc_graph_rn_2, "most_frequent_parasite_group")
compute_assortativity(largest_cc_graph_rn_2, "animals_group") """
# Out:
# Graph simple count and disparity filter with threshold 0.5 Assortativities:
# Assortativity for 'most_frequent_locality': 0.7538810746023188
# Assortativity for 'most_frequent_parasite_group': 0.39754334693375304
# Assortativity for 'animals_group': 0.766739851544915
#
# Graph simple count and disparity filter with threshold 0.57 Assortativities:
# Assortativity for 'most_frequent_locality': 0.7591851694062133
# Assortativity for 'most_frequent_parasite_group': 0.3983976544733757
# Assortativity for 'animals_group': 0.777054831937878
#
# Graph resource allocation and naive with threshold 0.0349 on score (not nij) Assortativities:
# Assortativity for 'most_frequent_locality': 0.6937394928883506
# Assortativity for 'most_frequent_parasite_group': 0.3908561665212139
# Assortativity for 'animals_group': 0.7007194370436343
#
# Graph resource allocation and naive with threshold 0.01745 on score (not nij) Assortativities:
# Assortativity for 'most_frequent_locality': 0.7239208469035852
# ...

# %%
def compute_communities_and_modularity(graph):
    results = {}
    
    # Label Propagation
    label_communities = list(nx.community.label_propagation_communities(graph))
    label_modularity = nx.community.modularity(graph, label_communities)
    results['label_propagation'] = {
        'communities': label_communities,
        'modularity': label_modularity
    }
    print("Label Propagation - Modularity:", label_modularity) 
    
    # Greedy Modularity Maximization
    greedy_communities = list(nx.community.greedy_modularity_communities(graph))
    greedy_modularity = nx.community.modularity(graph, greedy_communities)
    results['greedy_modularity'] = {
        'communities': greedy_communities,
        'modularity': greedy_modularity
    }
    print("Greedy Modularity Maximization - Modularity:", greedy_modularity) 

    # Louvain
    louvain_communities = list(nx.community.louvain_communities(graph))
    louvain_modularity = nx.community.modularity(graph, louvain_communities)
    results['Louvain'] = {
        'communities': louvain_communities,
        'modularity': louvain_modularity
    }

    print("Louvain - Modularity:", louvain_modularity)

    return results

graph_rn_1_results = compute_communities_and_modularity(graph_rn_1)    

graph_rn_2_results = compute_communities_and_modularity(graph_rn_2)

graph_sd_1_results = compute_communities_and_modularity(graph_sd_1)

graph_sd_2_results = compute_communities_and_modularity(graph_sd_2)



""" #Compute communities and modularity for each graph
print("Graph simple count and disparity filter with threshold 0.5:")
graph_sd_1_results = compute_communities_and_modularity(graph_sd_1)

print("\nGraph simple count and disparity filter with threshold 0.57:")
graph_sd_2_results = compute_communities_and_modularity(graph_sd_2)

print("\nGraph resource allocation and naive with threshold 0.0349 on score (not nij):")
graph_rn_1_results = compute_communities_and_modularity(graph_rn_1)

print("\nGraph resource allocation and naive with threshold 0.01745 on score (not nij):")
graph_rn_2_results = compute_communities_and_modularity(graph_rn_2) """
# Out:
# Label Propagation - Modularity: 0.7909635602082592
# Greedy Modularity Maximization - Modularity: 0.9459048273963154
# Louvain - Modularity: 0.9491213440614987
# Label Propagation - Modularity: 0.7461017807461997
# Greedy Modularity Maximization - Modularity: 0.8381236850678812
# Louvain - Modularity: 0.8916852802051496
# Label Propagation - Modularity: 0.661667513132169
# Greedy Modularity Maximization - Modularity: 0.5990917461674404
# Louvain - Modularity: 0.7084307693837738
# Label Propagation - Modularity: 0.673937991179117
# Greedy Modularity Maximization - Modularity: 0.6268886003965377
# Louvain - Modularity: 0.7307382095313679
# ...

# %%
# For the first graph
num_label_prop_communities_rn_1 = len(graph_rn_1_results['label_propagation']['communities'])
num_greedy_mod_communities_rn_1 = len(graph_rn_1_results['greedy_modularity']['communities'])
num_louvain_communities_rn_1 = len(graph_rn_1_results['Louvain']['communities'])



print("Graph rn_1:")
print("  Label Propagation Communities:", num_label_prop_communities_rn_1)
print("  Greedy Modularity Communities:", num_greedy_mod_communities_rn_1)
print("  Louvain Communities:", num_louvain_communities_rn_1)

# For the second graph
num_label_prop_communities_rn_2 = len(graph_rn_2_results['label_propagation']['communities'])
num_greedy_mod_communities_rn_2 = len(graph_rn_2_results['greedy_modularity']['communities'])
num_louvain_communities_rn_2 = len(graph_rn_2_results['Louvain']['communities'])

print("Graph rn_2:")
print("  Label Propagation Communities:", num_label_prop_communities_rn_2)
print("  Greedy Modularity Communities:", num_greedy_mod_communities_rn_2)
print("  Louvain Communities:", num_louvain_communities_rn_2)

# For the third graph
num_label_prop_communities_sd_1 = len(graph_sd_1_results['label_propagation']['communities'])
num_greedy_mod_communities_sd_1 = len(graph_sd_1_results['greedy_modularity']['communities'])
num_louvain_communities_sd_1 = len(graph_sd_1_results['Louvain']['communities'])

print("Graph sd_1:")
print("  Label Propagation Communities:", num_label_prop_communities_sd_1)
print("  Greedy Modularity Communities:", num_greedy_mod_communities_sd_1)
print("  Louvain Communities:", num_louvain_communities_sd_1)

# For the fourth graph
num_label_prop_communities_sd_2 = len(graph_sd_2_results['label_propagation']['communities'])
num_greedy_mod_communities_sd_2 = len(graph_sd_2_results['greedy_modularity']['communities'])
num_louvain_communities_sd_2 = len(graph_sd_2_results['Louvain']['communities'])

print("Graph sd_2:")
print("  Label Propagation Communities:", num_label_prop_communities_sd_2)
print("  Greedy Modularity Communities:", num_greedy_mod_communities_sd_2)
print("  Louvain Communities:", num_louvain_communities_sd_2)


print(graph_sd_1_results['Louvain']['communities'])
# Out:
# Graph rn_1:
#   Label Propagation Communities: 876
#   Greedy Modularity Communities: 76
#   Louvain Communities: 66
# Graph rn_2:
#   Label Propagation Communities: 1081
#   Greedy Modularity Communities: 113
#   Louvain Communities: 59
# Graph sd_1:
#   Label Propagation Communities: 483
#   Greedy Modularity Communities: 106
#   Louvain Communities: 40
# Graph sd_2:
#   Label Propagation Communities: 441
#   Greedy Modularity Communities: 90
#   Louvain Communities: 36
# ...

# %%
""" print(len(graph_sd_1_results['label_propagation']['communities']), len(graph_sd_1_results['greedy_modularity']['communities']), len(graph_sd_1_results['Louvain']['communities']))
num_components1 = nx.number_connected_components(graph_sd_1)
print(f"Number of connected components: {num_components1}")

print(len(graph_sd_2_results['label_propagation']['communities']), len(graph_sd_2_results['greedy_modularity']['communities']), len(graph_sd_2_results['Louvain']['communities']))
num_components2 = nx.number_connected_components(graph_sd_2)
print(f"Number of connected components: {num_components2}")

print(len(graph_rn_1_results['label_propagation']['communities']), len(graph_rn_1_results['greedy_modularity']['communities']), len(graph_rn_1_results['Louvain']['communities']))
num_components3 = nx.number_connected_components(graph_rn_1)
print(f"Number of connected components: {num_components3}")

print(len(graph_rn_2_results['label_propagation']['communities']), len(graph_rn_2_results['greedy_modularity']['communities']), len(graph_rn_2_results['Louvain']['communities']))
num_components4 = nx.number_connected_components(graph_rn_2)
print(f"Number of connected components: {num_components4}") """
# Out:
# ' print(len(graph_sd_1_results[\'label_propagation\'][\'communities\']), len(graph_sd_1_results[\'greedy_modularity\'][\'communities\']), len(graph_sd_1_results[\'Louvain\'][\'communities\']))\nnum_components1 = nx.number_connected_components(graph_sd_1)\nprint(f"Number of connected components: {num_components1}")\n\nprint(len(graph_sd_2_results[\'label_propagation\'][\'communities\']), len(graph_sd_2_results[\'greedy_modularity\'][\'communities\']), len(graph_sd_2_results[\'Louvain\'][\'communities\']))\nnum_components2 = nx.number_connected_components(graph_sd_2)\nprint(f"Number of connected components: {num_components2}")\n\nprint(len(graph_rn_1_results[\'label_propagation\'][\'communities\']), len(graph_rn_1_results[\'greedy_modularity\'][\'communities\']), len(graph_rn_1_results[\'Louvain\'][\'communities\']))\nnum_components3 = nx.number_connected_components(graph_rn_1)\nprint(f"Number of connected components: {num_components3}")\n\nprint(len(graph_rn_2_results[\'label_propagat
# ...

# %%
from sklearn.metrics import adjusted_mutual_info_score

# Function to compute Adjusted Mutual Information (AMI)
def compute_ami(graph, communities, attribute):
    # Map nodes to their community labels
    node_to_community = {}
    for idx, community in enumerate(communities):
        for node in community:
            node_to_community[node] = idx

    # Extract the ground-truth labels based on the given attribute
    node_labels = []
    community_labels = []
    for node in graph.nodes():
        if attribute in graph.nodes[node]:
            node_labels.append(graph.nodes[node][attribute])
            community_labels.append(node_to_community[node])

    # Compute AMI
    ami_score = adjusted_mutual_info_score(node_labels, community_labels)
    return ami_score

# Function to compute AMI for all attributes and both community detection methods
def compute_ami_for_graph(graph, results, attributes):
    ami_results = {}
    
    for method in ['label_propagation', 'greedy_modularity' ,'Louvain']:
        print(f"\n{method.capitalize()} Communities:")
        communities = results[method]['communities']
        ami_results[method] = {}
        
        for attribute in attributes:
            ami = compute_ami(graph, communities, attribute)
            ami_results[method][attribute] = ami
            print(f"Adjusted Mutual Information (AMI) for {attribute}: {ami}")
    
    return ami_results

# List of attributes
attributes = ["most_frequent_locality", "most_frequent_parasite_group", "animals_group"]

#Compute AMI for each graph and attribute
print("Graph simple count and disparity filter with threshold 0.5:")
ami_results_sd_1 = compute_ami_for_graph(largest_cc_graph_sd_1, graph_sd_1_results, attributes)

print("\nGraph simple count and disparity filter with threshold 0.57:")
ami_results_sd_2 = compute_ami_for_graph(largest_cc_graph_sd_2, graph_sd_2_results, attributes)

print("\nGraph resource allocation and naive with threshold 0.0349 on score (not nij):")
ami_results_rn_1 = compute_ami_for_graph(largest_cc_graph_rn_1, graph_rn_1_results, attributes)

print("\nGraph resource allocation and naive with threshold 0.01745 on score (not nij):")
ami_results_rn_2 = compute_ami_for_graph(largest_cc_graph_rn_2, graph_rn_2_results, attributes)
# Out:
# Graph simple count and disparity filter with threshold 0.5:
#
# Label_propagation Communities:
# Adjusted Mutual Information (AMI) for most_frequent_locality: 0.3384148417497056
# Adjusted Mutual Information (AMI) for most_frequent_parasite_group: 0.08950065001954959
# Adjusted Mutual Information (AMI) for animals_group: 0.3882386039053766
#
# Greedy_modularity Communities:
# Adjusted Mutual Information (AMI) for most_frequent_locality: 0.23335578435570956
# Adjusted Mutual Information (AMI) for most_frequent_parasite_group: 0.06891912950926611
# Adjusted Mutual Information (AMI) for animals_group: 0.39500210418615844
#
# Louvain Communities:
# Adjusted Mutual Information (AMI) for most_frequent_locality: 0.2856476294030411
# Adjusted Mutual Information (AMI) for most_frequent_parasite_group: 0.08033992715082486
# Adjusted Mutual Information (AMI) for animals_group: 0.44005469431499433
#
# Graph simple count and disparity filter with threshold 0.57:
#
# ...

# %%
# pikle the results / community partitions
with open('../data/communities_and_modularity/1_simple_disparity_filter.pkl', 'wb') as f:
    pickle.dump(graph_sd_1_results, f)
with open('../data/communities_and_modularity/2_simple_disparity_filter.pkl', 'wb') as f:
    pickle.dump(graph_sd_2_results, f)
with open('../data/communities_and_modularity/1_resource_allocation_naive.pkl', 'wb') as f:
    pickle.dump(graph_rn_1_results, f)
with open('../data/communities_and_modularity/2_resource_allocation_naive.pkl', 'wb') as f:
    pickle.dump(graph_rn_2_results, f)
