# %%
import pandas as pd

df = pd.read_csv('./data/nodes.csv')

# %%
df[' locality'].unique()
# Out:
# array(['Northeast Atlantic', nan, 'Western Mediterranean',
#        'Atlantic Ocean', 'Lake Malawi', 'United States', 'Wisconsin',
#        'Zimbabwe', 'Yugoslavia', 'Western Europe', 'Sea of Okhotsk',
#        'Canada', 'Japan', 'Pacific Ocean',
#        'Yukon + Northwest Territories', 'Utah', 'Ontario', 'Mexico',
#        'Lake Baikal', 'Ukraine, incl. Moldavia', 'Southwest Atlantic',
#        'Oceanic Islands', 'Southwest Indian Ocean', 'Antarctic Ocean',
#        'Philippines', 'Southern S. America', 'Queensland', 'Indian Ocean',
#        'Tyrrhenian Sea', 'Northern Indian Ocean', 'Australia',
#        'Norwegian Sea', 'Uruguay', 'Puerto Rico', 'Thailand', 'Red Sea',
#        'Persian Gulf', 'Southeast Atlantic', 'South China Sea',
#        'Oriental', 'Pakistan', 'Western coast of India', 'Arctic Ocean',
#        'Western coast of British Isles', 'West Coast of Norway',
#        'Russia (Asian)', 'South America', 'Virginia', 'Wyoming',
# ...

# %%
mapping = [
    "Atlantic Ocean",
    None,
    "Water Europe",
    "Atlantic Ocean",
    "Water Africa",
    "North America",
    "North America",
    "Africa",
    "Europe",
    "Europe",
    "Water Asia",
    "North America",
    "Asia",
    "Pacific Ocean",
    "North America",
    "North America",
    "North America",
    "North America",
    "Water Asia",
    "Europe",
    "Atlantic Ocean",
    "Australia",
    "Indian Ocean",
    "Southern Ocean",
    "Asia",
    "South America",
    "Australia",
    "Indian Ocean",
    "Water Europe",
    "Indian Ocean",
    "Australia",
    "Water Europe",
    "South America",
    "North America",
    "Asia",
    "Water Africa",
    "Water Asia",
    "Atlantic Ocean",
    "Water Asia",
    "Asia",
    "Asia",
    "Asia",
    "Asia",
    "Arctic Ocean",
    "Europe",
    "Europe",
    "Asia",
    "South America",
    "North America",
    "North America",
    "Asia",
    "Europe",
    "Water Europe",
    "Water Europe",
    "Africa",
    "Asia",
    "Water North America",
    "South America",
    "Water North America",
    "Indian Ocean",
    "Water Europe",
    "North America",
    "Europe",
    "Europe",
    "Europe",
    "Asia",
    "Water Europe",
    "Europe",
    "Asia",
    "Africa",
    "North America",
    "Australia",
    "Australia",
    "Australia",
    "Australia",
    "Australia",
    "Europe",
    "Asia",
    "Europe",
    "Asia",
    "Europe",
    "Asia",
    "Asia",
    "Asia",
    "North America",
    "North America",
    "North America",
    "Europe",
    "Asia",
    "Europe",
    "Europe",
    "North America",
    "Water North America",
    "North America",
    "Water North America",
    "North America",
    "North America",
    "Africa",
    "Africa",
    "Africa",
    "Africa",
    "Africa",
    "Africa",
    "Africa",
    "North America",
    "North America",
    "Africa",
    "Africa",
    "Asia",
    "Asia",
    "Europe",
    "Asia",
    "Africa",
    "Africa",
    "Water Asia",
    "Europe",
    "Europe",
    "Antarctica",
    "Antarctica",
    "Asia",
    "Asia",
    "North America",
    "Africa",
    "Africa",
    "Africa",
    "Australia",
    "Africa",
    "Africa",
    "Asia",
    "Australia",
    "Europe",
    "Africa",
    "Asia",
    "Water Africa",
    "Europe",
    "North America",
    "North America",
    "Europe",
    "North America",
    "Europe",
    "Europe",
    "Africa",
    "Water Europe",
    "Europe",
    "Water Europe",
    "Asia",
    "Asia",
    "Water North America",
    "Africa",
    "Africa",
    "Africa",
    "South America",
    "Asia",
    "Africa",
    "Africa",
    "Australia",
    "Africa",
    "Asia",
    "Asia",
    "Asia",
    "Africa",
    "Europe",
    "Europe",
    "North America",
    "North America",
    "North America",
    "North America",
    "North America",
    "Africa",
    "Africa",
    "North America",
    "Africa",
    "North America",
    "North America",
    "Europe",
    "Asia",
    "Europe",
    "Africa",
    "Australia",
    "Australia",
    "Africa",
    "Asia",
    "Europe",
    "North America",
    "Europe",
    "Africa",
    "Africa"
]

# %%
c = list(df[' locality'].unique())

# %%
m = list(zip(c, mapping))

# %%
m
# Out:
# [('Northeast Atlantic', 'Atlantic Ocean'),
#  (nan, None),
#  ('Western Mediterranean', 'Water Europe'),
#  ('Atlantic Ocean', 'Atlantic Ocean'),
#  ('Lake Malawi', 'Water Africa'),
#  ('United States', 'North America'),
#  ('Wisconsin', 'North America'),
#  ('Zimbabwe', 'Africa'),
#  ('Yugoslavia', 'Europe'),
#  ('Western Europe', 'Europe'),
#  ('Sea of Okhotsk', 'Water Asia'),
#  ('Canada', 'North America'),
#  ('Japan', 'Asia'),
#  ('Pacific Ocean', 'Pacific Ocean'),
#  ('Yukon + Northwest Territories', 'North America'),
#  ('Utah', 'North America'),
#  ('Ontario', 'North America'),
#  ('Mexico', 'North America'),
#  ('Lake Baikal', 'Water Asia'),
#  ('Ukraine, incl. Moldavia', 'Europe'),
#  ('Southwest Atlantic', 'Atlantic Ocean'),
#  ('Oceanic Islands', 'Australia'),
#  ('Southwest Indian Ocean', 'Indian Ocean'),
#  ('Antarctic Ocean', 'Southern Ocean'),
#  ('Philippines', 'Asia'),
#  ('Southern S. America', 'South America'),
#  ('Queensland', 'Australia'),
# ...

# %%
localities = [
    'Northeast Atlantic', None, 'Western Mediterranean',
    'Atlantic Ocean', 'Lake Malawi', 'United States', 'Wisconsin',
    'Zimbabwe', 'Yugoslavia', 'Western Europe', 'Sea of Okhotsk',
    'Canada', 'Japan', 'Pacific Ocean', 'Yukon + Northwest Territories',
    'Utah', 'Ontario', 'Mexico', 'Lake Baikal', 'Ukraine, incl. Moldavia',
    'Southwest Atlantic', 'Oceanic Islands', 'Southwest Indian Ocean',
    'Antarctic Ocean', 'Philippines', 'Southern S. America', 'Queensland',
    'Indian Ocean', 'Tyrrhenian Sea', 'Northern Indian Ocean', 'Australia',
    'Norwegian Sea', 'Uruguay', 'Puerto Rico', 'Thailand', 'Red Sea',
    'Persian Gulf', 'Southeast Atlantic', 'South China Sea', 'Oriental',
    'Pakistan', 'Western coast of India', 'Arctic Ocean',
    'Western coast of British Isles', 'West Coast of Norway',
    'Russia (Asian)', 'South America', 'Virginia', 'Wyoming',
    'Armenia', 'Italy', 'Black Sea', 'Sea of Marmara',
    'NW African coast', 'Yakut ASSR', 'Caribbean Sea', 'Venezuela',
    'Gulf of Mexico', 'Southern Indian Ocean', 'Caspian Sea',
    'New Brunswick + Nova Scotia', 'Finland', 'Poland', 'Lithuania',
    'South Korea', 'North Sea', 'Georgia (USSR)', 'Uzbekistan',
    'Tunisia', 'Washington', 'Tasmania', 'South Australia', 'Victoria',
    'Western Australia', 'New South Wales', 'Balearic Islands',
    'Vietnam', 'Austria', 'Middle East + Asia Minor', 'Czechoslovakia',
    'United Arab Emirates', 'Taiwan', 'Southeast Asia', 'Central America',
    'Cuba', 'Antilles', 'Bulgaria', 'Turkmenistan', 'Spain + Andalusia',
    'Hungary', 'Manitoba', 'Lake Superior', 'West Virginia', 'Lake Huron',
    'Saskatchewan', 'Quebec', 'Uganda + Burundi + Rwanda', 'Zambia',
    'Sudan', 'Zaire', 'Central Africa', 'Egypt', 'Kenya', 'Costa Rica',
    'Nicaragua', 'Chad', 'Ghana', 'Far East', 'Mongolia', 'Russia (European)',
    'Tadzhikistan', 'Tanzania', 'Ethiopia (incl. Dhibouti)', 'Sea of Japan',
    'Finno-Karelian ASSR', 'Greece', 'South Sandwich Islands', 'South Georgia',
    'Kazakstan', 'Kirgizia', 'Panama', 'North Africa', 'Namibia',
    'South Africa', 'New Zealand', 'Nigeria', 'Senegal + The Gambia + Guinea-Bassau',
    'Sri Lanka', 'Papua New Guinea', 'Sardinia', 'Somalia', 'Turkey',
    'Lake Tanganyika', 'Byelorussia', 'Lesser Antilles',
    'Dominican Republic + Haiti', 'Iceland', 'Greenland', 'Switzerland + Lichtenstein',
    'Benin + Togo + Ghana', 'Azov Sea', 'Norway', 'Eastern Mediterranean',
    'Azerbaidzan', 'Sabah', 'Lake Michigan', 'Transvaal', 'Ivory Coast',
    'Gabon + Congo + Equatorial Guinea', 'Surinam', 'Sumatra', 'Togo',
    'Sierra Leone', 'Society Islands (incl. Tahiti)', 'Malawi',
    'Saudi Arabia', 'Syria', 'Southern Yemen + Yemen', 'Mozambique',
    'Spitzbergen (Svalbard)', 'Sweden', 'Nova Scotia', 'Bahamas',
    'Haiti', 'Cayman Islands', 'Jamaica', 'Mali + Burkina Faso',
    'Botswana', 'Newfoundland', 'Central African Republic', 'Honduras',
    'Guatemala', 'Corsica', 'Hong Kong', 'Gibraltar',
    'Guinea + Sierra Leone + Liberia', 'Samoa Islands', 'Solomon Islands',
    'Seychelles', 'West Irian', 'Portugal', 'Labrador + Newfoundland',
    'Denmark', 'Liberia', 'The Gambia'
]

classified_localities = [
    "Atlantic Ocean",          # Northeast Atlantic (part of the Atlantic)
    None,                      # NaN or None
    "Atlantic Ocean",          # Western Mediterranean (connected to Atlantic Ocean)
    "Atlantic Ocean",          # Atlantic Ocean
    "Water Africa",            # Lake Malawi (inland water in Africa)
    "North America",           # United States (in North America)
    "North America",           # Wisconsin (in North America)
    "Africa",                  # Zimbabwe (in Africa)
    "Europe",                  # Yugoslavia (in Europe)
    "Europe",                  # Western Europe (in Europe)
    "Pacific Ocean",           # Sea of Okhotsk (marginal sea of the Pacific)
    "North America",           # Canada (in North America)
    "Asia",                    # Japan (in Asia)
    "Pacific Ocean",           # Pacific Ocean
    "North America",           # Yukon + Northwest Territories (in North America)
    "North America",           # Utah (in North America)
    "North America",           # Ontario (in North America)
    "North America",           # Mexico (in North America)
    "Water Asia",              # Lake Baikal (inland water in Asia)
    "Europe",                  # Ukraine, incl. Moldavia (in Europe)
    "Atlantic Ocean",          # Southwest Atlantic (part of the Atlantic)
    "Pacific Ocean",           # Oceanic Islands (islands in the Pacific)
    "Indian Ocean",            # Southwest Indian Ocean (part of the Indian Ocean)
    "Southern Ocean",          # Antarctic Ocean (the Southern Ocean)
    "Asia",                    # Philippines (in Asia)
    "South America",           # Southern S. America (region in South America)
    "Australia",               # Queensland (in Australia)
    "Indian Ocean",            # Indian Ocean
    "Atlantic Ocean",          # Tyrrhenian Sea (part of the Mediterranean connected to Atlantic)
    "Indian Ocean",            # Northern Indian Ocean (part of the Indian Ocean)
    "Australia",               # Australia (continent)
    "Atlantic Ocean",          # Norwegian Sea (marginal sea of the Atlantic)
    "South America",           # Uruguay (in South America)
    "North America",           # Puerto Rico (in North America)
    "Asia",                    # Thailand (in Asia)
    "Indian Ocean",            # Red Sea (connected to Indian Ocean)
    "Indian Ocean",            # Persian Gulf (connected to Indian Ocean)
    "Atlantic Ocean",          # Southeast Atlantic (region of Atlantic)
    "Pacific Ocean",           # South China Sea (marginal sea of Pacific)
    "Asia",                    # Oriental (likely meaning Eastern Asia)
    "Asia",                    # Pakistan (in Asia)
    "Asia",                    # Western coast of India (in Asia)
    "Arctic Ocean",            # Arctic Ocean
    "Europe",                  # Western coast of British Isles (in Europe)
    "Europe",                  # West Coast of Norway (in Europe)
    "Asia",                    # Russia (Asian) (in Asia)
    "South America",           # South America (continent)
    "North America",           # Virginia (in North America)
    "North America",           # Wyoming (in North America)
    "Asia",                    # Armenia (in Asia)
    "Europe",                  # Italy (in Europe)
    "Atlantic Ocean",          # Black Sea (connected to Mediterranean and Atlantic)
    "Atlantic Ocean",          # Sea of Marmara (connected to Black Sea and Atlantic)
    "Africa",                  # NW African coast (in Africa)
    "Asia",                    # Yakut ASSR (in Asia)
    "Atlantic Ocean",          # Caribbean Sea (marginal sea of Atlantic)
    "South America",           # Venezuela (in South America)
    "Atlantic Ocean",          # Gulf of Mexico (marginal sea of Atlantic)
    "Indian Ocean",            # Southern Indian Ocean (part of Indian Ocean)
    "Water Asia",              # Caspian Sea (inland water in Asia)
    "North America",           # New Brunswick + Nova Scotia (in North America)
    "Europe",                  # Finland (in Europe)
    "Europe",                  # Poland (in Europe)
    "Europe",                  # Lithuania (in Europe)
    "Asia",                    # South Korea (in Asia)
    "Atlantic Ocean",          # North Sea (marginal sea of Atlantic)
    "Europe",                  # Georgia (USSR) (in Europe)
    "Asia",                    # Uzbekistan (in Asia)
    "Africa",                  # Tunisia (in Africa)
    "North America",           # Washington (in North America)
    "Australia",               # Tasmania (in Australia)
    "Australia",               # South Australia (in Australia)
    "Australia",               # Victoria (in Australia)
    "Australia",               # Western Australia (in Australia)
    "Australia",               # New South Wales (in Australia)
    "Europe",                  # Balearic Islands (in Europe)
    "Asia",                    # Vietnam (in Asia)
    "Europe",                  # Austria (in Europe)
    "Asia",                    # Middle East + Asia Minor (in Asia)
    "Europe",                  # Czechoslovakia (in Europe)
    "Asia",                    # United Arab Emirates (in Asia)
    "Asia",                    # Taiwan (in Asia)
    "Asia",                    # Southeast Asia (in Asia)
    "North America",           # Central America (in North America)
    "North America",           # Cuba (in North America)
    "North America",           # Antilles (in North America)
    "Europe",                  # Bulgaria (in Europe)
    "Asia",                    # Turkmenistan (in Asia)
    "Europe",                  # Spain + Andalusia (in Europe)
    "Europe",                  # Hungary (in Europe)
    "North America",           # Manitoba (in North America)
    "Water North America",     # Lake Superior (inland water in North America)
    "North America",           # West Virginia (in North America)
    "Water North America",     # Lake Huron (inland water in North America)
    "North America",           # Saskatchewan (in North America)
    "North America",           # Quebec (in North America)
    "Africa",                  # Uganda + Burundi + Rwanda (in Africa)
    "Africa",                  # Zambia (in Africa)
    "Africa",                  # Sudan (in Africa)
    "Africa",                  # Zaire (in Africa)
    "Africa",                  # Central Africa (in Africa)
    "Africa",                  # Egypt (in Africa)
    "Africa",                  # Kenya (in Africa)
    "North America",           # Costa Rica (in North America)
    "North America",           # Nicaragua (in North America)
    "Africa",                  # Chad (in Africa)
    "Africa",                  # Ghana (in Africa)
    "Asia",                    # Far East (region in Asia)
    "Asia",                    # Mongolia (in Asia)
    "Europe",                  # Russia (European) (in Europe)
    "Asia",                    # Tadzhikistan (in Asia)
    "Africa",                  # Tanzania (in Africa)
    "Africa",                  # Ethiopia (incl. Dhibouti) (in Africa)
    "Pacific Ocean",           # Sea of Japan (marginal sea of Pacific)
    "Europe",                  # Finno-Karelian ASSR (in Europe)
    "Europe",                  # Greece (in Europe)
    "Antarctica",              # South Sandwich Islands (in Antarctica)
    "Antarctica",              # South Georgia (associated with Antarctica)
    "Asia",                    # Kazakstan (in Asia)
    "Asia",                    # Kirgizia (in Asia)
    "North America",           # Panama (in North America)
    "Africa",                  # North Africa (in Africa)
    "Africa",                  # Namibia (in Africa)
    "Africa",                  # South Africa (in Africa)
    "Australia",               # New Zealand (in Australasia)
    "Africa",                  # Nigeria (in Africa)
    "Africa",                  # Senegal + The Gambia + Guinea-Bassau (in Africa)
    "Asia",                    # Sri Lanka (in Asia)
    "Australia",               # Papua New Guinea (in Australia/Oceania)
    "Europe",                  # Sardinia (in Europe)
    "Africa",                  # Somalia (in Africa)
    "Asia",                    # Turkey (in Asia)
    "Water Africa",            # Lake Tanganyika (inland water in Africa)
    "Europe",                  # Byelorussia (in Europe)
    "North America",           # Lesser Antilles (in North America)
    "North America",           # Dominican Republic + Haiti (in North America)
    "Europe",                  # Iceland (in Europe)
    "North America",           # Greenland (in North America)
    "Europe",                  # Switzerland + Lichtenstein (in Europe)
    "Africa",                  # Benin + Togo + Ghana (in Africa)
    "Atlantic Ocean",          # Azov Sea (connected to Atlantic via Black Sea)
    "Europe",                  # Norway (in Europe)
    "Atlantic Ocean",          # Eastern Mediterranean (part of Mediterranean -> Atlantic)
    "Asia",                    # Azerbaidzan (in Asia)
    "Asia",                    # Sabah (in Asia)
    "Water North America",     # Lake Michigan (inland water in North America)
    "Africa",                  # Transvaal (in Africa)
    "Africa",                  # Ivory Coast (in Africa)
    "Africa",                  # Gabon + Congo + Equatorial Guinea (in Africa)
    "South America",           # Surinam (in South America)
    "Asia",                    # Sumatra (in Asia)
    "Africa",                  # Togo (in Africa)
    "Africa",                  # Sierra Leone (in Africa)
    "Pacific Ocean",           # Society Islands (incl. Tahiti) (in Pacific)
    "Africa",                  # Malawi (in Africa)
    "Asia",                    # Saudi Arabia (in Asia)
    "Asia",                    # Syria (in Asia)
    "Asia",                    # Southern Yemen + Yemen (in Asia)
    "Africa",                  # Mozambique (in Africa)
    "Europe",                  # Spitzbergen (Svalbard) (in Europe)
    "Europe",                  # Sweden (in Europe)
    "North America",           # Nova Scotia (in North America)
    "North America",           # Bahamas (in North America)
    "North America",           # Haiti (in North America)
    "North America",           # Cayman Islands (in North America)
    "North America",           # Jamaica (in North America)
    "Africa",                  # Mali + Burkina Faso (in Africa)
    "Africa",                  # Botswana (in Africa)
    "North America",           # Newfoundland (in North America)
    "Africa",                  # Central African Republic (in Africa)
    "North America",           # Honduras (in North America)
    "North America",           # Guatemala (in North America)
    "Europe",                  # Corsica (in Europe)
    "Asia",                    # Hong Kong (in Asia)
    "Europe",                  # Gibraltar (in Europe)
    "Africa",                  # Guinea + Sierra Leone + Liberia (in Africa)
    "Pacific Ocean",           # Samoa Islands (in Pacific)
    "Pacific Ocean",           # Solomon Islands (in Pacific)
    "Africa",                  # Seychelles (in Africa)
    "Asia",                    # West Irian (in Asia)
    "Europe",                  # Portugal (in Europe)
    "North America",           # Labrador + Newfoundland (in North America)
    "Europe",                  # Denmark (in Europe)
    "Africa",                  # Liberia (in Africa)
    "Africa",                  # The Gambia (in Africa)
]

print(classified_localities)
# Out:
# ['Atlantic Ocean', None, 'Atlantic Ocean', 'Atlantic Ocean', 'Water Africa', 'North America', 'North America', 'Africa', 'Europe', 'Europe', 'Pacific Ocean', 'North America', 'Asia', 'Pacific Ocean', 'North America', 'North America', 'North America', 'North America', 'Water Asia', 'Europe', 'Atlantic Ocean', 'Pacific Ocean', 'Indian Ocean', 'Southern Ocean', 'Asia', 'South America', 'Australia', 'Indian Ocean', 'Atlantic Ocean', 'Indian Ocean', 'Australia', 'Atlantic Ocean', 'South America', 'North America', 'Asia', 'Indian Ocean', 'Indian Ocean', 'Atlantic Ocean', 'Pacific Ocean', 'Asia', 'Asia', 'Asia', 'Arctic Ocean', 'Europe', 'Europe', 'Asia', 'South America', 'North America', 'North America', 'Asia', 'Europe', 'Atlantic Ocean', 'Atlantic Ocean', 'Africa', 'Asia', 'Atlantic Ocean', 'South America', 'Atlantic Ocean', 'Indian Ocean', 'Water Asia', 'North America', 'Europe', 'Europe', 'Europe', 'Asia', 'Atlantic Ocean', 'Europe', 'Asia', 'Africa', 'North America', 'Australia', 'Aus
# ...

# %%
list(zip(localities, classified_localities))
# Out:
# [('Northeast Atlantic', 'Atlantic Ocean'),
#  (None, None),
#  ('Western Mediterranean', 'Atlantic Ocean'),
#  ('Atlantic Ocean', 'Atlantic Ocean'),
#  ('Lake Malawi', 'Water Africa'),
#  ('United States', 'North America'),
#  ('Wisconsin', 'North America'),
#  ('Zimbabwe', 'Africa'),
#  ('Yugoslavia', 'Europe'),
#  ('Western Europe', 'Europe'),
#  ('Sea of Okhotsk', 'Pacific Ocean'),
#  ('Canada', 'North America'),
#  ('Japan', 'Asia'),
#  ('Pacific Ocean', 'Pacific Ocean'),
#  ('Yukon + Northwest Territories', 'North America'),
#  ('Utah', 'North America'),
#  ('Ontario', 'North America'),
#  ('Mexico', 'North America'),
#  ('Lake Baikal', 'Water Asia'),
#  ('Ukraine, incl. Moldavia', 'Europe'),
#  ('Southwest Atlantic', 'Atlantic Ocean'),
#  ('Oceanic Islands', 'Pacific Ocean'),
#  ('Southwest Indian Ocean', 'Indian Ocean'),
#  ('Antarctic Ocean', 'Southern Ocean'),
#  ('Philippines', 'Asia'),
#  ('Southern S. America', 'South America'),
#  ('Queensland', 'Australia'),
# ...
