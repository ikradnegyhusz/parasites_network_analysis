# %% [markdown]
# Why do we use average, not minimum or maximum?
# - minimum would mean taking the weight of directed link from the animal with lower share, maximum with greater. Minimum means that we can safely assume that both of them are ???? TO do -
# - average - ok, fine.
# I think taking the minimum could make sense because it guarantees that both species are similar of at least this bar to each other.
# But for now we go with average

# %% [markdown]
# You project hosts onto parasites
# then, you want to answer if this projection was good?
# Maybe it's OK?

# %%
import networkx as nx
import numpy as np
import pandas as pd
from networkx.algorithms import bipartite
import pickle

# %%
df1 = pd.read_csv('./full_data.csv')
df1.columns
y = set(df1['Parasite'].unique())

# %%
df2 = pd.read_csv('./data/nodes.csv')
df2.columns

x = set(df2[df2[' is_host']==0][' name'])

# %%
x-y
# Out:
# {'Capillaria linsi',
#  'Hymenolepis rangoonica',
#  'Paragymnophallus kinsellai',
#  'Longicollum indicum',
#  'Camallanides dhamini',
#  'Didymocystis kamegaii',
#  'Loxogenoides bicolor',
#  'Karachitrema trilobata',
#  'Diplotriaena couturieri',
#  'Echinostoma jurini',
#  'Taenia polycalcaria',
#  'Leidynemella fusiformis',
#  'Pleurogenoides compactus',
#  'Strigea elliptica',
#  'Parasitodiplogaster yoponema',
#  'Oochoristica trachysauri',
#  'Physaloptera tigrinae',
#  'Proteocephalus magna',
#  'Erilepturus karachiensis',
#  'Cercaria agarwali',
#  'Magnacetabulum glandocaudum',
#  'Pristotrema manteri',
#  'Davainea capillaris',
#  'Hystrignathus ferox',
#  'Davainea macrocirrosa',
#  'Glomericirrus propositus',
#  'Endocotyle bushi',
#  'Rhabdochona uca',
#  'Rictularia jodhpurensis',
#  'Paragonimus proliferus',
#  'Bucephalus oari',
#  'Pallisentis vietnamensis',
#  'Cercaria srivastavi',
#  'Amphibiocapillaria texensis',
#  'Sonsinotrema calloti',
#  'Porrocaecum pentkotai',
#  'Camallanus tholukodensis',
#  'Stegodexamene watsoni',
#  'Paragonimus peruvianus',
#  'Tetragonocephalum varium',
#  'Ophidascaris excavata',
#  'Blattophila supellaima',
#  'Brenesia chabaudi',
#  'Physaloptera dilatata',
#  'Orchipedum formosum',
#  'Serrasentis engraulisi',
#  'Indocucullanus malvanae',
#  'Probothriocephalus muelleri',
#  'Aephnidiogenes dollfusi',
#  'Gendria ranarum',
#  'Spiculopteragia ateis',
#  'Halipegus szidati',
#  'Thelastoma rovinjense',
#  'Plasmiorchis bengalensis',
#  'Davainea emperus',
#  'Monostomum minutissimum',
#  'Spinitectus multipapillatus',
#  'Spauligodon cabrerae',
#  'Cercaria hastata',
#  'Rhadinorhynchus vancleavei',
#  'Microrchis megacotyle',
#  'Cercaria chillavanensis',
#  'Gymnorhynchus reptans',
#  'Pleurogenes hepaticola',
#  'Meteterakis paucipapillosa',
#  'Crassicutis caranxi',
#  'Euzetiella tetraphylliformis',
#  'Lutztrema dicruri',
#  'Hurleytrematoides chaetodoni',
#  'Acanthostomum scyphocephalum',
#  'Pseudoparabaris parabaris',
#  'Parahemiurus dogieli',
#  'Skrjabinodon heliocostai',
#  'Paragonimus jiangsuensis',
#  'Rauschiella ranae',
#  'Phaneropsolus philanderi',
#  'Opisthodiscus cyanophylectis',
#  'Helicometra selaroides',
#  'Cucullanus interrogativus',
#  'Ornithocapillaria quiscali',
#  'Taenia motacillaeprovincialis',
#  'Zonothrix gladius',
#  'Rictularia carstairsi',
#  'Diplodiscus khyberensis',
#  'Camallanus ranae',
#  'Cucullanus kakinadensis',
#  'Haplometrana simibramae',
#  'Hymenolepis solitaria',
#  'Plagioporus hunghuaensis',
#  'Allacanthochasmus artus',
#  'Camallanus alatae',
#  'Gibsoniela mandube',
#  'Cystodiplostomum hollyi',
#  'Lecithaster atropi',
#  'Pseudorhadinorhynchus dussumieri',
#  'Distomum flexum',
#  'Cucullanus heliomartinsi',
#  'Plagiorchis parumbursatus',
#  'Heterorchis protopteri',
#  'Cercaria marcianae',
#  'Cucullanus oswaldocruzi',
#  'Cylicodontophorus reineckei',
#  'Phyllodistomum undulans',
#  'Cercaria bhaleraoi',
#  'Dogielina inexpectata',
#  'Paragendria seenghali',
#  'Hymenolepis bahli',
#  'Neoaplectana feltiae',
#  'Hexacanalis thapari',
#  'Chaetophallus setigera',
#  'Toxocara lyncis',
#  'Camallanus magnorugosus',
#  'Cephalobellus lobulata',
#  'Hymenolepis tubicirrosa',
#  'Diplodiscus lali',
#  'Indocucullanus karachii',
#  'Ganeo macrocotyle',
#  'Oxysomatium anurae',
#  'Apocreadium synagris',
#  'Cercaria patzcuarensis',
#  'Quadrigyrus cholodkowskyi',
#  'Falcaustra kaverii',
#  'Hymenolepis brasiliensis',
#  'Alcicornis hainanensis',
#  'Angusticaecum numidicum',
#  'Cyathocotyle lutzi',
#  'Buckleytrema postacetabulorchis',
#  'Nematodirus lamae',
#  'Hymenolepis bacillaris',
#  'Vampirolepis macroti',
#  'Daubaylia pearsoni',
#  'Corynosoma alaskensis',
#  'Dinosoma synaphobranchi',
#  'Meteterakis bufonis',
#  'Polylecithus oviformis',
#  'Pleurogenes gastroporus',
#  'Cercaria longicauda',
#  'Binema medinae',
#  'Oswaldocruzia mitunagai',
#  'Sharpilia australiensis',
#  'Brachycoelium longleyi',
#  'Emoleptalea exilis',
#  'Lepidapedon alvigae',
#  'Philophthalmus larsoni',
#  'Parasitorhabditis platidontus',
#  'Loxogenes liberum',
#  'Maricostula cenatica',
#  'Gorgoderina beninensis',
#  'Rhinebothroides circularisi',
#  'Glirovingylus rodentium',
#  'Cucullanus bilqeesi',
#  'Protrellus kunckeli',
#  'Parahemiurus ambassicola',
#  'Paradistomum fudingensis',
#  'Oswaldocruzia michaeli',
#  'Ophiotaenia hyalina',
#  'Rhabpanus ossiculum',
#  'Spirura tamarini',
#  'Nematobothrioides kalikali',
#  'Trichofreitasia lenti',
#  'Mathevotaenia bivittata',
#  'Decemtestis varmai',
#  'Setaria altaica',
#  'Nicollodiscus gangeticus',
#  'Crenosoma hermani',
#  'Lecithochirium callaoensis',
#  'Psammomermis canterburiensis',
#  'Paramphistomum microbothrioides',
#  'Vermaia sorrakowahi',
#  'Vianella argentina',
#  'Serrasentis golvani',
#  'Phyllodistomum enterocolpium',
#  'Gastromermis boophthorae',
#  'Neodiplostomum leei',
#  'Dirofilaria aethiops',
#  'Cercaria levantina',
#  'Protrellatus indica',
#  'Panuwa chauhani',
#  'Raillietina tetragonoides',
#  'Dichelyne hardellus',
#  'Hymenolepis lobata',
#  'Srivastavatrema brevibursae',
#  'Patagifer consimilis',
#  'Brachylecithum microrchis',
#  'Zonorchis cylindriformis',
#  'Paragonimus minqingensis',
#  'Haematoloechus exoterorchis',
#  'Dilepis orientalis',
#  'Mesomermis delponteiana',
#  'Oxynema suricattae',
#  'Rhabdochona mesopotamica',
#  'Andrya americana',
#  'Steganoderma macrophallus',
#  'Neogymnorhynchus magna',
#  'Tetrabothrius porrigens',
#  'Schistosoma intercalatum/haematobium',
#  'Paralecithodendrium aranhoai',
#  'Balanobothrium trygoni',
#  'Ophidascaris agkistrodontis',
#  'Parasitorhabditis autographi',
#  'Pseudoprosotocus ranarum',
#  'Opisthomonorcheides indicus',
#  'Amplicaecum tetradonti',
#  'Ceylonocotyle dicranocoelium',
#  'Inglamidium akodon',
#  'Philophthalmus rhionica',
#  'Pedibothrium veravalensis',
#  'Oxyuris megaloon',
#  'Tetrabothrius longicolle',
#  'Hystrignathus rescens',
#  'Stadelmannia circumcincta',
#  'Echinorhynchus hepaticus',
#  'Flagellotrema convolutum',
#  'Cosmocerca rara',
#  'Litomosa jairajpurii',
#  'Pallisentis clupei',
#  'Parasitodiplogaster bullenema',
#  'Stephanofilaria kaeli',
#  'Acanthocephalus luzus',
#  'Parametorchis canadensis',
#  'Cooperia chabaudi',
#  'Aploparaksis caballeroi',
#  'Pseudidiogenes flagellum',
#  'Stephanostomum theraponi',
#  'Amphistomum conicum',
#  'Neoallassostoma lobata',
#  'Hysterothylacium rhamdiae',
#  'Philometra baylisi',
#  'Polydelphis brachycheilos',
#  'Hymenolepis globulosa',
#  'Hudsonia allocytti',
#  'Cercaria tapidis',
#  'Chenia cheni',
#  'Pleurogenoides orientalis',
#  'Johnstonia alatum',
#  'Paranisakis johrii',
#  'Glypthelmins festina',
#  'Leidynema delatorrei',
#  'Ornithotrema longibursatum',
#  'Camallanus gomtii',
#  'Thysanocephalum karachii',
#  'Tenuiproboscis edmondi',
#  'Cladolecithotrema callionymi',
#  'Cordonema ardeai',
#  'Opisthogonimus pereirai',
#  'Halipegus lermensis',
#  'Himantocestus blanksoni',
#  'Ophiotaenia saphenus',
#  'Philometra katsuwoni',
#  'Hemistomum epatula',
#  'Bothriocephalus uncinatus',
#  'Camallanus vlastimili',
#  'Julinea granatensis',
#  'Opecoeloides pedicathedrae',
#  'Parahemiurus collichthydis',
#  'Crenosoma semiarmatum',
#  'Delicata uncinata',
#  'Eulimdana juventarum',
#  'Stictodora martini',
#  'Cercaria leyteensis',
#  'Arhythmacanthus pseudobagri',
#  'Amphicaecum excavatum',
#  'Monodontella giraffae',
#  'Trypanoxyuris goeldi',
#  'Oswaldocruzia cassonei',
#  'Bulbodacnitis globosa',
#  'Ophidascaris cameroni',
#  'Falcaustra falcata',
#  'Cylindrotaenia jaegerskioeldi',
#  'Hymenolepis rectacantha',
#  'Opistholebes microovus',
#  'Cruznema lincolnensis',
#  'Choanotaenia rotunda',
#  'Botulus alepidosauri',
#  'Hysterothylacium nellorensis',
#  'Pseudotelorchis yacarei',
#  'Rhabdias hermafrodita',
#  'Carmyerius chabaudi',
#  'Derogenes chelidonichthys',
#  'Echinorhynchus jucundus',
#  'Paramaritremopsis stunkardi',
#  'Cyclocoelum paradoxum',
#  'Paragyliauchen chaetodontis',
#  'Opisthogonimus fonsecai',
#  'Parasitorhabditis hectographi',
#  'Timonia caballeroi',
#  'Proteocephalus hemioliopteri',
#  'Oxysomatium srinagarensis',
#  'Cephalobellus leuckarti',
#  'Cosmocercoides barodensis',
#  'Rhabdochona vagabundai',
#  'Skrjabinodon trimorphi',
#  'Bianium bombayensis',
#  'Calicophoron papilligerum',
#  'Lyperosomum gorbunovi',
#  'Camallanus siluranae',
#  'Wellcomia decorata',
#  'Amphibiophilus egerniae',
#  'Proterodiplostomum tumidilum',
#  'Breviscolex naldurgensis',
#  'Brachylaima funambuli',
#  'Trypanoxyuris clementinae',
#  'Ganeo microacetabulus',
#  'Paratimonia magnipharynx',
#  'Podocotyle longiforme',
#  'Alloglossidium hirudicola',
#  'Tetragonocephalum janardane',
#  'Apocreadium vinodae',
#  'Opisthomonorcheides karwarensis',
#  'Pseudantorchis thalassomae',
#  'Procamallanus chimusensis',
#  'Opecoeloides fugus',
#  'Amplicaecum monitor',
#  'Propharyngodon ranae',
#  'Rhoporhynchus lini',
#  'Lepocreadium xanthichthydis',
#  'Echinorhynchus longicollis',
#  'Tanaisia augusta',
#  'Hymenolepis magniovata',
#  'Rhabditis sp.',
#  'Dibothrium sulcatum',
#  'Abbreviata nyassae',
#  'Cercaria assimineae',
#  'Clinostomum hornum',
#  'Homalometron senegalense',
#  'Telorchis guptai',
#  'Hypoporus phylloides',
#  'Leucochloridium peturbatum',
#  'Gyliauchen thalassamae',
#  'Bursaphelenchus xylophilus',
#  'Haematoloechus similiplexus',
#  'Prohemistomum sinensis',
#  'Didymocystoides submentalis',
#  'Agamofilaria oxyura',
#  'Spinitectus ophiocephali',
#  'Stictodora hancocki',
#  'Tetraster siamensis',
#  'Longitrema hangzhouensis',
#  'Hymenolepis longiovata',
#  'Artionema hartwichi',
#  'Micropleura trionyxi',
#  'Hugotdiplogaster neozelandia',
#  'Polyonchobothrium indicum',
#  'Oligolecithoides trilobatus',
#  'Derogenes ruber',
#  'Strigea brasiliana',
#  'Neocruzia morleyi',
#  'Cercaria banglabazarensis',
#  'Plerurus trichiuri',
#  'Ichthyotrema vogelsangi',
#  'Erilepturus formosae',
#  'Dibothriocephalus wilsoni',
#  'Bianium purii',
#  'Elaeolenchus parthenonema',
#  'Rhabdias ceylanicum',
#  'Neoechinorhynchus bangoni',
#  'Heligmosomum mongolicum',
#  'Lecithocladium hanumanthai',
#  'Ochoterenella figueroai',
#  'Hysterothylacium thalassini',
#  'Neopronocephalus kachugae',
#  'Carpobothrium rhinobati',
#  'Mesocoelium elongatus',
#  'Raillietnema minor',
#  'Plehnia japonica',
#  'Sinicovothylax mapaensis',
#  'Cercaria visakhapatnamensis',
#  'Johnstonmawsonia campana-rougetae',
#  'Decemtestis mystusi',
#  'Strongyloides ophiusensis',
#  'Protechinostoma mucronisertulatum',
#  'Diaschistorchis lateralis',
#  'Echinuria minor',
#  'Bucephalus arabiana',
#  'Westella sulina',
#  'Haematoloechus similis',
#  'Pleurogenoides solus',
#  'Lecithochirium margolisi',
#  'Annelamphistoma elegans',
#  'Parathelandros canariensis',
#  'Hymenolepis ibidis',
#  'Prosotocus gussevi',
#  'Urotrema glyptothoraci',
#  'Travassossinema mirabile',
#  'Contracaecum nototheniae',
#  'Acanthocheilus quadridentatus',
#  'Camallanus thapari',
#  'Rictularia insapida',
#  'Dirofilaria subcutaenea',
#  'Ctenascarophis lesteri',
#  'Oligacanthorhynchus kamerunensis',
#  'Phyllodistomum leiocassis',
#  'Oswaldocruzia moraveci',
#  'Neocucullanus multipapillatus',
#  'Oswaldofilaria innisfailensis',
#  'Cercaria fluviocinguli',
#  'Acanthocolpus lutijanusi',
#  'Pseudhymenolepis suncusi',
#  'Codonocephalus mutabilis',
#  'Acanthocolpus acanthocepolae',
#  'Thubunaea brooki',
#  'Amphitretus settii',
#  'Taenia scolopacis',
#  'Tergestia atulis',
#  'Amphibiophilus ranae',
#  'Cylicostrongylus trichiurusi',
#  'Capillaria muris',
#  'Brientrema cavasiustus',
#  'Apatemon congolensis',
#  'Cercaria nervosa',
#  'Proteocephalus bunpurwaensis',
#  'Cercaria chungathi',
#  'Philometra jordanoi',
#  'Taenia filariformis',
#  'Platycladorchis microacetabularis',
#  'Ochoterenella nanolarvata',
#  'Tanqua anomala',
#  'Artigasia longicauda',
#  'Lepotrema incisum',
#  'Syphacia longaecauda',
#  'Paratetrochetus hansoni',
#  'Cosmocerca panamaensis',
#  'Hexamermis ovistriata',
#  'Prodistomum gracile',
#  'Proctoeces longisacum',
#  'Prosotocus partapus',
#  'Paramphistomum explanatum',
#  'Spirura rothschildi',
#  'Paracapillaria spratti',
#  'Cylindrotaenia quadrijugosa',
#  'Maculifer dayawanensis',
#  'Paraoxyascaris travassosi',
#  'Cestocephalus serratus',
#  'Acanthobothrium atahualpai',
#  'Stilestrongylus moreli',
#  'Pallisentis allahabadi',
#  'Nigerina hardoiensis',
#  'Tylodelphys rapidulus',
#  'Parafilaria multipapillosa',
#  'Acanthosentis arii',
#  'Tanaisia precaria',
#  'Cercaria nigrocaudata',
#  'Sharpilia dollfusi',
#  'Indocucullanus guerreroi',
#  'Tylodelphys dissimilis',
#  'Acanthobothrium parvum',
#  'Phyllodistomum magnificum',
#  'Molineus felineus',
#  'Madathamugadia hiepei',
#  'Plagiorchis taiwanensis',
#  'Glypthelmins ramitesticularis',
#  'Homungella baviense',
#  'Cercaria machilipatnamensis',
#  'Gogatea serpentium',
#  'Cosmocercoides multipapillata',
#  'Ommatobrephus lobatum',
#  'Bivesicula obovata',
#  'Skrjabinodon mabuyae',
#  'Mesodiplostomum gladiolum',
#  'Spironoura wuyiensis',
#  'Caluromytrema martindelcampoi',
#  'Megacetabulum coracinum',
#  'Physaloptera abbreviata',
#  'Amplicaecum ranae',
#  'Hymenolepis andrejewoi',
#  'Preptetos laguncula',
#  'Paracryptogonimus mexicanus',
#  'Helicometra pleurogrammi',
#  'Hymenolepis gaugi',
#  'Steinernema weiseri',
#  'Hirundinicola parvirostris',
#  'Pseudomonorcheides ditrematis',
#  'Diploproctodaeum momoaafata',
#  'Pseudopecoelus akamachi',
#  'Centrorhynchus saxicoloides',
#  'Pseudotobothrium arii',
#  'Anterovitellosum indicum',
#  'Hysterolecitha ovarilobulus',
#  'Genarchopsis bangladensis',
#  'Stephanostomum microcephalum',
#  'Oochoristica ameivae',
#  'Vampirolepis bahli',
#  'Acanthobothrium chengi',
#  'Prosorhynchus piranhus',
#  'Cosmocercoides kumaoni',
#  'Dicheilonema fusiformis',
#  'Paracaryophyllaeus ostiobramensis',
#  'Pseudosiphoderoides rotivarizera',
#  'Aplectana /Cosmocercoides',
#  'Bucephalus harpodontis',
#  'Philophthalmus burrili',
#  'Asymphylodora rhinogobio',
#  'Rhynchopharynx formionis',
#  'Tetrarhynchus discophorus',
#  'Rhabdias tobagoensis',
#  'Lepidapedon blairi',
#  'Bathymermis simuliae',
#  'Echinostoma bancrofti',
#  'Schizamphistomoides taiwanense',
#  'Cercaria pernaviridis',
#  'Cercaria johrii',
#  'Notocotylus atlanticus',
#  'Pseudolepidapedon hydrolagi',
#  'Spirocamallanus ditchelli',
#  'Cephalobellus jewari',
#  'Didymocystis margolisi',
#  'Didymocylindrus simplex',
#  'Amphicaecum orientalis',
#  'Strongyloides bufonis',
#  'Hartertia obesa',
#  'Cercaria kuntzi',
#  'Porrocaecum phalacrocoracis',
#  'Sypharista cynocephali',
#  'Brachylecithum alfortanse',
#  'Parahemiurus trachichthodi',
#  'Distomum histrix',
#  'Senga raoi',
#  'Pseudobunocotyla clupanodonis',
#  'Carlosia tijucana',
#  'Coeuritrema oschmarini',
#  'Filaria tuberosa',
#  'Gorgoderina translucida',
#  'Acanthobothrium quadripartitum',
#  'Cercaria minus',
#  'Ascaris rajae',
#  'Hystrignathus papillophorus',
#  'Limnoderetrema macrophallus',
#  'Thelastoma retrovulvaris',
#  'Ascocotyle sexidigita',
#  'Patagifer fraternus',
#  'Pleurogenoides freycineti',
#  'Probstmayria tapiri',
#  'Travassostrongylus travassosi',
#  'Microphalloides liaoningensis',
#  'Synodontisia moraveci',
#  'Cercaria hartmanae',
#  'Cercaria nordica',
#  'Yungasicola travassosi',
#  'Haplorchoides gwaliorensis',
#  'Procamallanus ophicephalus',
#  'Lecithaster intermedius',
#  'Zonocotyloides haroldtravassosi',
#  'Cercaria cystophora',
#  'Philometroides anguillae',
#  'Echinuria cincli',
#  'Capillaria bufonis',
#  'Anthocephalum centrurum',
#  'Philometra polynemi',
#  'Stephanostomum argyrosomi',
#  'Pallisentis panadei',
#  'Psilotrema tuberculata',
#  'Decemtestis asymmetricum',
#  'Oochoristica okinawaensis',
#  'Pseudocreadium hainanensis',
#  'Heligmosomum asakawai',
#  'Plerurus asterocongeri',
#  'Foleyellides striatus',
#  'Lepidapedon clavatum',
#  'Pseudabbreviata amaniensis',
#  'Lutztrema macrorhynchii',
#  'Abbreviata turkomanica',
#  'Poracanthium ghanensis',
#  'Gnathostoma accipitris',
#  'Kalicephalus assimilis',
#  'Pacudistoma turgida',
#  'Amphicotyle typica',
#  'Tylodelphys diaphanus',
#  'Macyella posthogonoporus',
#  'Echinobreviceca coelorhynchae',
#  'Zeylanema nodulosus',
#  'Caryophyllaeus kashmirensis',
#  'Hypocreadium dampieriae',
#  'Lobatovitelliovarium fusiforme',
#  'Hymenolepis minimedius',
#  'Centrorhynchus indicus',
#  'Catenotaenia gracilae',
#  'Coitocaecum latum',
#  'Cardiocephalus brandesii',
#  'Gorgoderina diaster',
#  'Phyllodistomum mugilis',
#  'Microparyphium asotum',
#  'Capillaria sonsinoi',
#  'Dirofilaria subdermata',
#  'Musculovesicula trichiuri',
#  'Pulchrocephala simulatilis',
#  'Spauligodon eremiasin',
#  'Papillosetaria veversi',
#  'Aponurus clupanodontis',
#  'Telosentis mizellei',
#  'Phyllodistomum rhyacosideronis',
#  'Xyo xiphacanthus',
#  'Lepidapedon arlenae',
#  'Prosotocus dorsoporus',
#  'Parasitorhabditis hylurgi',
#  'Talpicola klossae',
#  'Zonocotyle haroldtravassosi',
#  'Spinitectus seenghalai',
#  'Choledocystus vesicalis',
#  'Alloplectognathotrema tsushimaense',
#  'Parasaurositus yamagutii',
#  'Paragonimus paishuihoensis',
#  'Lyperosomum byrdi',
#  'Cosmocercoides nainitalensis',
#  'Hexaglandula mutabilis',
#  'Renicola melastigmai',
#  'Longior zayasi',
#  'Heligmosomoides asakawae',
#  'Opecoelus nipponicus',
#  'Psettarium japonicum',
#  'Uvulifer semicircumcisus',
#  'Cercaria hofufi',
#  'Stilestrongylus valdivianus',
#  'Skrjabinodon poicilandri',
#  'Raillietina longicollis',
#  'Spauligodon timbavatiensis',
#  'Nematobothrium okujamai',
#  'Spauligodon saxicolae',
#  'Kathlania stromatei',
#  'Cucullanus serratus',
#  'Rhadinorhynchus cyprini',
#  'Ochoterenella guyanensis',
#  'Opisthioglyphe hinoi',
#  'Camallanus fotedari',
#  'Hymenolepis birmanica',
#  'Haematoloechus aubriae',
#  'Spauligodon vojteki',
#  'Lepidapedoides kalikali',
#  'Thwaitia bagri',
#  'Skrjabinocara timofejevi',
#  'Tetragonocephalum aurangabadensis',
#  'Brachyenteron japonicum',
#  'Mesocoelium zhejiangensis',
#  'Camallanus atropusi',
#  'Xyo utiaritensis',
#  'Centrocestus unequiorchalis',
#  'Auritelorchis harwoodi',
#  'Lecithocladium pagrosomi',
#  'Caluromytrema derbianus',
#  'Ditremamermis simuliae',
#  'Skrjabinopsolus sanyaensis',
#  'Healyum harenamica',
#  'Dirofilaria tawila',
#  'Drepanidotaenia caprimulgorum',
#  'Falcaustra annandalei',
#  'Hymenolepis chalinobi',
#  'Dinosoma hynnodi',
#  'Kachugotrema majumdari',
#  'Hymenocotta mugilis',
#  'Parasitodiplogaster pertusanema',
#  'Cercaria gyraulusi',
#  'Polycercus japonensis',
#  'Phyllotrema guangxiensis',
#  'Philophthalmus chrysommae',
#  'Eufilaria mcintoshi',
#  'Zonothrix galebi',
#  'Guptatrema papillonae',
#  'Diplodiscus minutus',
#  'Iheringtrema iheringi',
#  'Euparadistomum paraense',
#  'Lecithocladium dawesi',
#  'Cyclorchis amphileucus',
#  'Parapharyngodon margaritiferi',
#  'Prosorhynchoides philippinorum',
#  'Lepocreadium incisum',
#  'Capillaria ranae',
#  'Allomonorchis huangfuensis',
#  'Molinema barbarae',
#  'Rallitrema mordens',
#  'Travassossinema dechambrieri',
#  'Acanthosentis indicus',
#  'Pomphorhynchus jammuensis',
#  'Rhabdochona grandipapillata',
#  'Hymenolepis sciurina',
#  'Univitellannulocystis katsuwoni',
#  'Zonothrix helocharesae',
#  'Macdonaldius mackiewiczi',
#  'Cercaria varanasiensis',
#  'Mosgovoyia viscaciae',
#  'Nephrostomum robustum',
#  'Jauella glandicephala',
#  'Itaguaiana bromelicola',
#  'Artionema harturchi',
#  'Cercaria fraseri',
#  'Cercaria indicae',
#  'Oncicola travassosi',
#  'Raillietina paucicapsulata',
#  'Narsingiella narsingi',
#  'Heligmostrongylus elegans',
#  'Mehrarhynchus puriensis',
#  'Wellcomia evoluta',
#  'Nybelinia erythraea',
#  'Atractis testudinicola',
#  'Notoporus hystrix',
#  'Indocucullanus scienai',
#  'Vitta parvirostris',
#  'Thelastoma bivalvula',
#  'Lecithophyllum campbellmunroei',
#  'Podocotyle temensis',
#  'Rhabdochona guptii',
#  'Duthiersia sindensis',
#  'Acanthobothrium cartagenensis',
#  'Stichocotyle nephropis',
#  'Allopodocotyle margolisi',
#  'Amphibiocapillaria costacruzi',
#  'Cotylurus michiganensis',
#  'Ophiotaenia russelli',
#  'Cosmocerca timofejevoi',
#  'Blatticola blatti',
#  'Piriforma macrorhamphosi',
#  'Hapalorhynchus tchalimai',
#  'Ascaris scaphirhynchi',
#  'Echinobothrium acanthocolle',
#  'Dollfustrema hippocampi',
#  'Kowalewskiella grandihamata',
#  'Sobolevitaenia anthusi',
#  'Spirura narayani',
#  'Cotugnia latiproglottina',
#  'Helicometrina otolithi',
#  'Diaschistorchis takahashii',
#  'Neolebouria pentacerotis',
#  'Lecithobotrioides elongatus',
#  'Parasitorhabditis gracilis',
#  'Sobolevitaenia oitaensis',
#  'Paragendria baylisi',
#  'Paracanthorhynchus galaxiasus',
#  'Indorhynchus bilqeesae',
#  'Rhynchobothrium brevicolle',
#  'Platycladorchis macroacetabularis',
#  'Indodidymozoon metridion',
#  'Longior semialata',
#  'Dicrocoelioides petiolatum',
#  'Corrigia viktori',
#  'Crepidostomum transmarinum',
#  'Diplobulbus minutus',
#  'Davainea thapari',
#  'Paraisocoelium exorchis',
#  'Gigantodiscum yunnanse',
#  'Rudolphitrema rudolphii',
#  'Metorchis grusi',
#  'Acanthocephalus aenigma',
#  'Distomum instabile',
#  'Falcaustra puylaerti',
#  'Trichocephalus citellorum',
#  'Euparyphium murinum',
#  'Parvatrema timondavidi',
#  'Lepidapedon sammari',
#  'Tylodelphys thamnophidis',
#  'Cercaria micrura',
#  'Senga jagannathae',
#  'Befilaria pseudocordyli',
#  'Bothriocotyle solenosomum',
#  'Johnpearsonia egerniae',
#  'Procyrnea longialatus',
#  'Erilepturus trichiuri',
#  'Hypoderaeum vigi',
#  'Blattophila narayani',
#  'Cylindrocorpus inevectus',
#  'Plasmiorchis orientalis',
#  'Parasitodiplogaster nymphanema',
#  'Opisthioglyphe locellus',
#  'Nicolla pyriformis',
#  'Coeuritrema ocadiae',
#  'Cercaria globocaudata',
#  'Cercaria beaveri',
#  'Anthocephalus gracilis',
#  'Hymenolepis minutissima',
#  'Pleuropsolus insolens',
#  'Romanomermis chenzhouensis',
#  'Neoechinorhynchus devdevi',
#  'Paracapillaria huffmani',
#  'Hystrignathus pearsoni',
#  'Acanthobothrium marplatensis',
#  'Opegaster rectus',
#  'Pterygodermatites spinicaudatis',
#  'Cercaria branchyura',
#  'Cucullanus mugili',
#  'Gorgoderina valdiviensis',
#  'Syphacia eutamii',
#  'Zonorchis dureni',
#  'Entomelas kazachstanica',
#  'Parapharyngodon sceleratus',
#  'Vampirolepis sandogroundi',
#  'Avocettolepis vaginata',
#  'Africana bufonis',
#  'Monhystrium brevis',
#  'Cypseluritrematoides microvaei',
#  'Staphylocystis chattoraji',
#  'Lepidapedon genge',
#  'Heterophyes bitorquata',
#  'Parorientodiscus magnus',
#  'Contracaecum matwejewi',
#  'Pseudocryptotropa sichuanensis',
#  'Heteracanthocephalus peltorhamphi',
#  'Waltonella duboisi',
#  'Palaeorchis postovaris',
#  'Acanthobothrium zapterycum',
#  'Opisthorchis parageminus',
#  'Vampirolepis copihamata',
#  'Contracaecum scotti',
#  'Proalarioides kobayashii',
#  'Paryphostomum indicum',
#  'Echinobothrium deeghai',
#  'Gonapodasmius hainanensis',
#  'Nomimoscolex lopesi',
#  'Pseudogrillotia basipunctata',
#  'Hatterianema hollandei',
#  'Pycnadena lata',
#  'Gorgoderina rochalimai',
#  'Lecithobotrys helmymohamedi',
#  'Heterorchis senegalensis',
#  'Aponurus lizae',
#  'Mentecle magnifica',
#  'Transversohelmins borneoensis',
#  'Cercaria magnacauda',
#  'Pedibothrium zugei',
#  'Cercaria guaibensis',
#  'Proleptus niedmanni',
#  'Enterobius pygatrichus',
#  'Rhipidocotyle senegalensis',
#  'Opisthadena marina',
#  'Haematoloechus jamshedpurensis',
#  'Notoporus astrocongeris',
#  'Baruscapillaria cincli',
#  'Anomalostoma Cordeira,',
#  'Prosorhynchoides rioplatensis',
#  'Apororhynchus hemignathi',
#  'Plagiorchis moravicus',
#  'Phyllodistomum homoion',
#  'Angiostrongylus raillieti',
#  'Molinema algardneri',
#  'Schulzia melanostictusi',
#  'Telorchis dissimilis',
#  'Brachylecithum eophonae',
#  'Cercaria kazachstanica',
#  'Rhytidodes similis',
#  'Cucullanus theraponi',
#  'Neoprosorhynchus pseudecheneis',
#  'Philometra fujimotoi',
#  'Falcaustra trilokae',
#  'Homalometron longulum',
#  'Leucochloridium costaricense',
#  'Serrasentis psenesi',
#  'Hymenolepis septemsororum',
#  'Saccocoelioides leporinodus',
#  'Skrjabinozoum delamurei',
#  'Spinitectus ranae',
#  'Haematoloechus tejerae',
#  'Blatticola blattae',
#  'Astiotrema impletum',
#  'Lecithocladium karachii',
#  'Cercaria milleri',
#  'Taenia gaigeri',
#  'Gorgodera amplicava',
#  'Protrellus aureus',
#  'Kalicephalus indicus',
#  'Hypoechinorhynchus thermaceri',
#  'Bucephalus gangai',
#  'Dicelis kurashvilii',
#  'Enterobius presbytis',
#  'Buckleynema singhi',
#  'Cercaria meretrix',
#  'Cercaria chilkaensis',
#  'Vampirolepis peroryctis',
#  'Stomylotrema gratiosus',
#  'Paracephalochlamys papilionis',
#  'Oswaldocruzia heparia',
#  'Myliobatibothrium singhi',
#  'Bivesicula gymnothoracis',
#  'Homungella mekongianum',
#  'Stephanofilaria dedoesi',
#  'Pleurogonius malaclemys',
#  'Plectognathotrema ovata',
#  'Oxyascaris similis',
#  'Mesonema annamense',
#  'Hamacreadium gymnomuraenae',
#  'Habronema tomasi',
#  'Kachugotrema amboinensis',
#  'Decemtestis pseudolabri',
#  'Deretrema philippinensis',
#  'Morishitium distomatum',
#  'Acanthobothrium inbiorium',
#  'Thelastoma pterygoton',
#  'Madathamugadia ineichi',
#  'Seuratum indicum',
#  'Hexadontophorus ophisauri',
#  'Kowsalyabothrium indirapriyadarshinii',
#  'Stephanostomum polynemi',
#  'Pleurogenes lobatus',
#  'Lepotrema xanthichthydis',
#  'Bucephalus retractilis',
#  'Camallanus acaudatus',
#  'Prosogonotrema carangi',
#  'Neolitobothrium hexlacinatum',
#  'Andrincola mabianensis',
#  'Sureshia waghalaensis',
#  'Pleorchis uku',
#  'Biuterina pentamyzos',
#  'Lecithaster allocytti',
#  'Heligmosomum hasegawai',
#  'Steinernema intermedia',
#  'Rhipidocotyle ernsti',
#  'Lepocreadium navodoni',
#  'Canaaia obesa',
#  'Didymodiclinus branchialis',
#  'Diplopylidium udgirensis',
#  'Tetrabothrius joubini',
#  'Sterrhurus agarwali',
#  'Auritelorchis mcdonaldi',
#  'Pterobothrium malleum',
#  'Orientodiscus hendricksoni',
#  'Oesophagostomum roscoei',
#  'Cephalogonimus japonicus',
#  'Homalometron sophiae',
#  'Paraheligmonella interrogans',
#  'Paramonostomum obtortum',
#  'Rhabdochona onychostomi',
#  'Leptocreadium skrjabini',
#  'Halipegus zweifeli',
#  'Cercaria fursolensis',
#  'Crepidobothrium eirasi',
#  'Pseudolytocestus dayali',
#  'Raphidascaroides guttatus',
#  'Distomum ellipticum',
#  'Chrisomon polynemi',
#  'Sphaeridiotrema szidati',
#  'Thelastoma palmettum',
#  'Christiella pulchra',
#  'Aplectana praeputiale',
#  'Hymenolepis naja',
#  'Yamagutisentis nickoli',
#  'Preptetos pritchardae',
#  'Urorygma nanodes',
#  'Cercaria rishikondensis',
#  'Proctoeces ostreae',
#  'Hamacreadium lariosi',
#  'Capillaria cichlasomae',
#  'Cladorchis Fischr.',
#  'Cercaria manteri',
#  'Patagium lazarewi',
#  'Falcaustra fernandoi',
#  'Sanguinicola klamathensis',
#  'Cucullanellus peristedioni',
#  'Skrjabinocara viktori',
#  'Pseudolepidapedon brasiliensis',
#  'Diplotriaena pavlovskyi',
#  'Allotelorchis thomasi',
#  'Neogymnorhynchus platycephali',
#  'Prosogonotrema karachiense',
#  'Hairana sohali',
#  'Maritrema pyrenaica',
#  'Abbreviata affinis',
#  'Christiella macrovata',
#  'Hymenolepis lintonella',
#  'Lomasoma gracilis',
#  'Eustrongylides himalayii',
#  'Shorttia shortti',
#  'Siconema aculeatum',
#  'Klossiella longistoma',
#  'Cercaria apharyngeata',
#  'Linstowia brasiliensis',
#  'Grammocephalus hybridatus',
#  'Taenia blaniceps',
#  'Ancylostoma paraduodenale',
#  'Catadiscus cohni',
#  'Oswaldocruzia tunisiensis',
#  'Camallanus baylisi',
#  'Lophosicyadiplostomum Dubois,',
#  'Philometra gobioboti',
#  'Alaeuris quadrilabiata',
#  'Lyperosomum mosquensis',
#  'Dadaytremoides parauchenipteri',
#  'Piscicapillaria rhinobati',
#  'Plagioporus mujibi',
#  'Lecanicephalum peltatum',
#  'Pseudocoitocaecum thrissoclesis',
#  'Lecanicephalum ratnagiriensis',
#  'Batrachotrema pseudobagri',
#  'Procamallanus lutjanusi',
#  'Hemiperina nicolli',
#  'Tentacularia ilisha',
#  'Glaphyrostomum adhaerens',
#  'Levinseniella hunteri',
#  'Clinostomum chrysichthys',
#  'Glypthelmins shastai',
#  'Acanthocephaloides rhytidotes',
#  'Helostomatis muelleri',
#  'Indorhynchus arii',
#  'Neoaplectana thesami',
#  'Gnathostoma miyazakii',
#  'Dibothriocephalus antarcticus',
#  'Brahamputrotrema channa',
#  'Stephanostomum interruptum',
#  'Catadiscus propinquus',
#  'Hammerschmidtiella mackenziei',
#  'Xiphidiocercaria virgulate',
#  'Chambriella agostinhoi',
#  'Lyperosomum megastomum',
#  'Gomtia piscicola',
#  'Cercaria caudifina',
#  'Tetrochetus lesnoyi',
#  ...}

# %%
# Out:
# 5870

# %% [markdown]
# Below I'm assigning every property to the host, such that after projection we loose no data.
# Remember:
# - animalis might be victims of multiple paragroups
# - animals are assigned to one hostgroup.
# - animals might be in multiple localities.
# - parasites are assigned to one hostgroup and one paragroup and multiple localities

# %%
#projection of parasites onto hosts
#1-Mode projection
from utils import obtain_bipartite_animals_parasites_graph

badj, x, h = obtain_bipartite_animals_parasites_graph(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 5
#       1 #projection of parasites onto hosts
#       2 #1-Mode projection
#       3 from resource_allocation import obtain_bipartite_animals_parasites_graph
# ----> 5 badj, x, h = obtain_bipartite_animals_parasites_graph(df)
#
# File c:\Users\Maciej\Projects\parasites_network_analysis\resource_allocation.py:28, in obtain_bipartite_animals_parasites_graph(df)
#      26 if not G.has_node(el["Parasite"]):
#      27     locality = set()
# ---> 28     locality.add(locality_to_group[el["locality"]])
#      29     host_group = set()
#      30     host_group.add(el["hostgroup"])
#
# KeyError: 'Adriatic Sea'

# %%
h.nodes(data=True)['Acanthocephaloides propinquus']
# Out:
# {'bipartite': 1,
#  'host_group': {'Chondrichthyes', 'Teleostei'},
#  'para_group': 'Acanthocephala',
#  'locality': {'Adriatic Sea',
#   'Atlantic Ocean',
#   'Azov Sea',
#   'Black Sea',
#   'France',
#   'Northeast Atlantic',
#   'Sea of Marmara',
#   'Spain + Andalusia',
#   'Western Europe',
#   'Western Mediterranean'}}

# %%
bipartite_1_nodes = [n for n, data in G.nodes(data=True) if data.get('bipartite') == 1]

print(len(bipartite_1_nodes), bipartite_1_nodes)

projected_G = bipartite.projected_graph(G, bipartite_1_nodes)

print(len(projected_G.nodes(data=True)) ,len(projected_G.edges(data=True)))

# Copy attributes from the original graph G to projected_G
for node in projected_G.nodes():
    if node in G.nodes():
        # Copy all attributes of the node from the original graph
        projected_G.nodes[node].update(G.nodes[node])

# Save the graph to a file
with open('projected_graph_para.gpickle', 'wb') as f:
    pickle.dump(projected_G, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Projection of parasites onto  (hosts remain)
G = nx.Graph()

for i, el in df.iterrows():
    if G.has_node(el['Parasite']):
        G.add_node(el['Parasite'], bipartite=0)
    if G.has_node(el['Host']):
        G.nodes[el['Host']]['locality'].add(el['locality'])
        G.nodes[el['Host']]['para_group'].add(el['group'])
    else:
        locality = set()
        locality.add(el['locality'])
        para_group = set()
        para_group.add(el['group'])
        G.add_node(el['Host'], bipartite=1, host_group=el['hostgroup'], para_group=para_group, locality=locality)
    if not G.has_edge(el['Host'], el['Parasite']):
        G.add_edge(el['Host'], el['Parasite'], )

# %%
list(df.iterrows())[2]
# Out:
# (2,
#  Unnamed: 0.1                                                    2
#  Unnamed: 0                                                      4
#  Host                                            Gobius cruentatus
#  Parasite                            Acanthocephaloides propinquus
#  ParasiteFull       Acanthocephaloides propinquus (Dujardin, 1845)
#  group                                              Acanthocephala
#  locality                                             Adriatic Sea
#  hostgroup                                               Teleostei
#  animal_nodes                                                 1074
#  parasites_nodes                                             15711
#  Name: 2, dtype: object)

# %%
G.nodes(data=True)['Acanthocephaloides propinquus']
# Out:
# {'bipartite': 0}

# %%
max(dict(projected_G.degree()).values())

# %%
def stats(graph):
    graph_degrees=dict(graph.degree()).values()
    stats_dict={}
    #average degree
    stats_dict["average_degree"]=sum(graph_degrees)/graph.number_of_nodes()
    #max degree
    stats_dict["max_degree"]=max(graph_degrees)
    #min degree
    stats_dict["min_degree"]=min(graph_degrees)
    #percentage under the average
    stats_dict["percentage_under_average"]=len([d for d in graph_degrees if d < stats_dict["average_degree"]])/len(graph_degrees)
    #assortativity
    stats_dict["degree_assortativity"]=nx.degree_assortativity_coefficient(graph)
    #modularity
    communities = nx.community.greedy_modularity_communities(graph)
    stats_dict["modularity"]=nx.community.modularity(graph,communities)
    #...
    return stats_dict

# %%
s=stats(projected_G)

# %%
import json
with open('stats/1-mode projection.txt', 'w+') as convert_file: 
     convert_file.write(json.dumps(s))

# %%
# now we have directional weights, we need to get the average
from utils import average_resource_allocation
from utils import obtain_bipartite_animals_parasites_graph

badj, names = obtain_bipartite_animals_parasites_graph(df)

# %%
np.array([0])/np.int16(0)
# Out:
# C:\Users\Maciej\AppData\Local\Temp\ipykernel_28604\302908645.py:1: RuntimeWarning: invalid value encountered in divide
#   np.array([0])/np.int16(0)
# array([nan])

# %%
A = badj / badj.sum(axis=1)[:, np.newaxis]
# Out:
# C:\Users\Maciej\AppData\Local\Temp\ipykernel_28604\3967807711.py:1: RuntimeWarning: invalid value encountered in divide
#   A = badj / badj.sum(axis=1)[:, np.newaxis]

# %%
resource_allocation_weights.
# Out:
# array([[0.06535948, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.26136364, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.11666667, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.05631868, 0.03846154,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.03846154, 0.28846154,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
np.sum(resource_allocation_weights - resource_allocation_weights.T)
# Out:
# np.float64(0.0)

# %%
# ?average_resource_allocation
# Out:
# Signature: average_resource_allocation(badj: <built-in function array>) -> <built-in function array>
# Docstring: ddd
# File:      c:\users\maciej\projects\parasites_network_analysis\resource_allocation.py
# Type:      function

# %%
resource_allocation_weights = average_resource_allocation(badj)



# sanity check: symmetric matrix
print(np.allclose(resource_allocation_weights, resource_allocation_weights.T))
# compute the number of edges
print(np.count_nonzero(~np.isclose(resource_allocation_weights,0)) / 2)
# Out:
# True
# 528861.0

# %%
sum(resource_allocation_weights[1, :])

# %% [markdown]
# SELF LOOPS, are we care about them? not much tbh, we can remove them later.
# We don't care - we need to remove them later.

# %%
# are there any nans in resource_allocation_weights?
print(np.isnan(resource_allocation_weights).any())
# are there any inf in resource_allocation_weights?
print(np.isinf(resource_allocation_weights).any())
# are there any rows that sum to zero? (contains only zeros)
print(np.any(np.isclose(resource_allocation_weights.sum(axis=1), 0)))
# are there any rows which have only one non-zero element?
print(np.any(np.count_nonzero(resource_allocation_weights, axis=1) == 1))

# are there rows not summing to 1?
print(np.any(np.isclose(resource_allocation_weights.sum(axis=1), 1) == False))

# %%
# do the noise corrected disparity filter
# You don't need to take care of zeros, because these are going to be zero anyway after the filtering


node_edges_weights_sum = resource_allocation_weights.sum(axis=1)
edge_neighbourhood_weights_sums = node_edges_weights_sum[:, np.newaxis] - resource_allocation_weights
# are there rows that sum to zero? (contains only zeros)
print(np.any(np.isclose(edge_neighbourhood_weights_sums.sum(axis=1), 0)))

edge_neighbourhood_weights_means = edge_neighbourhood_weights_sums / (np.count_nonzero(resource_allocation_weights, axis=1) - 1)[:, np.newaxis]
# there could be 0/0, which would result in nan, replace these with zeros
# I don't understand how infs emerge, but they do, so replace them with zeros
edge_neighbourhood_weights_means = np.nan_to_num(edge_neighbourhood_weights_means, nan=0, posinf=0, neginf=0)

# above should not be symmetric
print(np.allclose(edge_neighbourhood_weights_means, edge_neighbourhood_weights_means.T))
disparity_filter = (edge_neighbourhood_weights_means + edge_neighbourhood_weights_means.T) / 2

# where the values are below the disparity filter, set to zero
filtered_weights = resource_allocation_weights.copy()
# check if both disparity filter and resource_allocation_weights are symmetric
print(np.allclose(disparity_filter, disparity_filter.T))
print(np.allclose(resource_allocation_weights, resource_allocation_weights.T))
filtered_weights[resource_allocation_weights < disparity_filter] = 0
filtered_weights

# %%
# check if the filtered weights are symmetric
print(np.allclose(filtered_weights, filtered_weights.T))
# compute the number of values which are not close to zero
print(np.count_nonzero(~np.isclose(filtered_weights, 0))/2)
filtered_weights.shape

# %% [markdown]
# Filtered weights is not symmetric, but has inconsistent amount of edges? :()

# %%
# create a new undirected graph with the filtered weights as adjacency matrix
G_filtered = nx.from_numpy_array(filtered_weights)
# reassign the node names and attributes
G_filtered = nx.relabel_nodes(G_filtered, dict(enumerate(bipartite_one_nodes)))
# add the attributes
for n, d in G.nodes(data=True):
    if d.get('bipartite') == 1:
        # drop the bipartite attribute
        d.pop('bipartite')
        G_filtered.nodes[n].update(d)
